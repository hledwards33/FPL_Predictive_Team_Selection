# %%
import pandas as pd
import seaborn as sns
import os
import matplotlib.pyplot as plt

# %%
data_path = os.getcwd() + "\Data\Transformed_Data\goalkeepers_correlated.csv"

df = pd.read_csv(data_path)
df.head()
# Out:
#    Unnamed: 0   Season            name position     team  total_points  bps  \
# 0           0  2021-22    David de Gea       GK  Man Utd             2   17
# 1           3  2021-22      Tom Heaton       GK  Man Utd             0    0
# 2           5  2021-22  Dean Henderson       GK  Man Utd             0    0
# 3          22  2021-22      Bernd Leno       GK  Arsenal             0    0
# 4          24  2021-22  Aaron Ramsdale       GK  Arsenal             3   23
#
#    clean_sheets  minutes  bonus  influence  ict_index  saves  value  selected  \
# 0             0       90      0       34.4        3.4      5     50    473518
# 1             0        0      0        0.0        0.0      0     40     42318
# 2             0        0      0        0.0        0.0      0     47     36124
# 3             0        0      0        0.0        0.0      0     46     83324
# 4             0       90      0       47.4        4.7      7     49   1125402
#
#    penalties_saved  transfers_in
# 0                0         19470
# 1                0           222
# 2                0            71
# 3                0           321
# 4                0         74772

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), annot=True, cmap='viridis')
# Out:
# <AxesSubplot:>
